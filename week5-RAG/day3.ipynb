# %% [markdown]
# Completing working code on creating Embeddings
#
# https://colab.research.google.com/drive/1wIlWSl8v50IST3wS9_4cjDs4H0vhgL5i#scrollTo=wp2upSSFB1VZ

# %% [markdown]
# ### Understanding more about embeddings
#
# https://colab.research.google.com/drive/1hcEbnUcPqFBQKe85alnlvdO1SnNqGpO4#scrollTo=EUj7bKz4ISi0
